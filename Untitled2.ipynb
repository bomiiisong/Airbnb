# %%
from selenium import webdriver
import time
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests


base_link = "https://www.goodchoice.kr/product/detail?ano=1592&adcno=1&sel_date=2021-02-08&sel_date2=2021-02-09"
html = urlopen(base_link)
bsObject = BeautifulSoup(html, "html.parser")

# %%
driver = webdriver.Chrome("./chromedriver.exe")
driver.get(base_link)

# %%
driver.find_elements_by_css_selector("div.score_cnt")[0].text
# Out:
# '9.3 추천해요  리뷰 5,709개'

# %%
bsObject.select("div.room")
# Out:
# [<div class="room">
#  <!-- 282 x 169 -->
#  <p class="pic_view"><img alt="페어필드 바이 메리어트 서울 | [레이트버드 21시 체크인] 프리미어 (킹 / 조식불포함)" class="lazy" data-original="//image.goodchoice.kr/resize_370x220/affiliate/2018/07/12/5b472f2e49fb1.jpg" src="//image.goodchoice.kr/resize_1000X500x0/adimg_new/list_none.png"/></p>
#  <div class="cal_bg">
#  <button type="button">닫기</button>
#  </div>
#  <strong class="title">[레이트버드 21시 체크인] 프리미어 (킹 / 조...</strong>
#  <div class="pic_wrap">
#  <!-- Mobile -->
#  <div class="gallery_m index_mobile swiper_detail">
#  <div class="swiper-container swiper-default">
#  <ul class="swiper-wrapper">
#  <li class="swiper-slide">
#  <img alt="페어필드 바이 메리어트 서울 | [레이트버드 21시 체크인] 프리미어 (킹 / 조식불포함)" class="swiper-lazy" data-src="//image.goodchoice.kr/resize_490x348/affiliate/2018/07/12/5b472f2e49fb1.jpg" src="//image.goodchoice.kr/images/web_v3/temp.png"/>
#  <div class="swiper-lazy-preloader swiper-lazy-preloader-white"></div>
#  </li>
#  <li class="swiper-slide">
# ...

# %%
req = requests.post(base_link)

# %%
req.content
# Out:
# b'\n<!doctype html>\n<html lang="ko">\n<head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta http-equiv="Content-Type">\n    <meta name="csrf-name" content="yeogi_token">\n\n    <meta name="description" content="\xed\x95\x9c\xea\xb0\x95\xea\xb3\xbc \xed\x95\xa8\xea\xbb\x98\xed\x95\x98\xeb\x8a\x94 \xed\x98\xb8\xed\x85\x94\xec\x9d\xb4\xeb\xa9\xb0, \xed\x9c\xb4\xec\x8b\x9d\xec\x9d\xb4 \xed\x95\x84\xec\x9a\x94\xed\x95\xa0 \xeb\x95\x8c \xec\x97\xac\xec\x9d\x98\xeb\x8f\x84 \xea\xb3\xb5\xec\x9b\x90\xec\x9c\xbc\xeb\xa1\x9c \xea\xb1\xb8\xec\x96\xb4\xeb\x82\x98\xea\xb0\x88 \xec\x88\x98 \xec\x9e\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4\r\xea\xb3\xa0\xec\xb2\x99\xeb\x8f\x94\xec\x97\x90\xec\x84\x9c \xec\xa7\x80\xed\x95\x98\xec\xb2\xa0 3\xec\xa0\x95\xea\xb1\xb0\xec\x9e\xa5\xec\x97\x90 \xec\x9c\x84\xec\xb9\x98\xed\x95\x
# ...
