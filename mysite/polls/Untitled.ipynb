# %%
import pandas as pd

df = pd.read_csv("Modify_and_Add_data.csv")

# %%
df
# Out:
#      roomID             room_name city               location   latitude  \
# 0     50000                 산너머펜션   경기      경기 양평군 옥천면 신복리 65  37.589086
# 1     50001            전라무주좋은인연펜션   전북   전북 무주군 설천면 삼공리 731-1  35.909324
# 2     50002      부여굿뜨래웰빙마을 글램핑코리아   충남    충남 부여군 부여읍 가탑리 94-3  36.275368
# 3     50006                 거제로펜션   경남     경남 거제시 동부면 학동리 233  34.778005
# 4     50007                  해뜨는집   강원   강원 춘천시 남산면 방곡리 401-3  37.806640
# ..      ...                   ...  ...                    ...        ...
# 269   50689  그랜드 머큐어 앰배서더 호텔앤레지던스   서울    서울 용산구 한강로3가 40-969  37.531596
# 270   50693                서브웨이호텔   경기      경기 시흥시 신천동 707-15  37.441372
# 271   50694                클로버리조트   경기  경기 가평군 가평읍 금대리 55-147  37.757702
# 272   50697                강화 리베라   인천    인천 강화군 길상면 온수리 43-2  37.646387
# 273   50699                더화이트호텔   강원     강원 평창군 봉평면 면온리 922  37.575846
#
#       longitude accomodation_type min_price rating general_review  \
# ...
