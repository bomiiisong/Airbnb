# %%
from selenium import webdriver
import time
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager , rc
import platform
import requests

# %%
df = pd.read_csv("Add_2columns.csv")
df.loc[0:5]["link"]

print(df.loc[100]["link"])
# Out:
# https://www.goodchoice.kr/product/detail?ano=50000

# %%
driver = webdriver.Chrome("./chromedriver.exe")


url = "https://www.airbnb.co.kr/s/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&source=structured_search_input_header&search_type=unknown&ne_lat=37.54816489011765&ne_lng=126.9680833181763&sw_lat=37.47000242928306&sw_lng=126.91280835479739&zoom=13&search_by_map=true"
# html = urlopen(url)
# bsObject = BeautifulSoup(html, "lxml")
# bsObject("div._10v3f8y9")
driver.get(url)

# %%
driver.find_element_by_css_selector("div._10v3f8y9 div").get_attribute('innerHTML')
# Out:
# '<style>\n.gm-style > div[tabindex="0"]:focus > :last-child::after{\n  border: 0px solid rgb(34, 34, 34);\n  bottom: 0;\n  content: " ";\n  display: block;\n  left: 0;\n  pointer-events: none;\n  position: absolute;\n  right: 0;\n  top: 0;\n}\n</style><div style="height: 100%; background-color: rgb(230, 227, 223); position: relative; overflow: hidden;"><div style="height: 100%; width: 100%; position: absolute; top: 0px; left: 0px; background-color: rgb(229, 227, 223);"><div class="gm-style" style="position: absolute; z-index: 0; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px;"><div tabindex="0" aria-label="Map" aria-roledescription="map" role="group" style="position: absolute; z-index: 0; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; cursor: url(&quot;https://maps.gstatic.com/mapfiles/openhand_8_8.cur&quot;), default; touch-action: none;"><div style="z-index: 1; position: absolute; left: 50%
# ...

# %%
import requests
html = requests.get(url).text

# %%
bsObject = BeautifulSoup(html, "lxml")
bsObject.select("div._16grqhk > div._1wcpzyga")
# Out:
# []
